# %%
marks = [50, 60, 80, 90, 83]
print (marks[4])
# Out:
# 83

# %%
a = [20, 30, 50]
a.append(80)
print(a)
# Out:
# [20, 30, 50, 80]

# %%
b= (10, 45, 66, 99, 56)
print (b[1])
# Out:
# 45

# %%
c= {10, 20, 30, 10}
print(c)
# Out:
# {10, 20, 30}

# %%
student = {"name" : "anu" , "age" : 45}
print(student['name'])
# Out:
# anu

# %%
name= "anu"
print(name[0])
print(name[-1])
# Out:
# a
# u
