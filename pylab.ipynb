# %%
a=int(input('enter number 1='))
b=int(input('enter number 2='))
print(a+b)
# Out:
# enter number 1=5
# enter number 2=5
# 10

# %%
age=int(input('ENTER AGE ='))
name=input('ENTER NAME =')
mark=float(input('ENTER MARK ='))
passed=input('PASS OR FAIL =')
# Out:
# ENTER AGE =33
# ENTER NAME =john
# ENTER MARK =99.7
# PASS OR FAIL =PASS

# %%
age=22
print(type(age))
# Out:
# <class 'int'>

# %%
side=float(input("ENTER THE SIDE="))
area= side * side
print('AREA OF THE SQUARE=',area)
# Out:
# ENTER THE SIDE=6
# AREA OF THE SQUARE= 36.0

# %%
number=int(input("ENTER AN INTEGER="))
prev=number-1
nextno=number+1
print('PREVIOUS NO=',prev)
print('NEXT NO=',nextno)
# Out:
# ENTER AN INTEGER=5
# PREVIOUS NO= 4
# NEXT NO= 6

# %%
principal=float(input('ENTER PRINCIPAL AMOUNT'))
years=float(input('ENTER THE YEAR'))
rate=float(input('ENTER THE RATE'))

interest=principal*years*rate/100
print("SIMPLE INTEREST=",interest)
# Out:
# ENTER PRINCIPAL AMOUNT10000
# ENTER THE YEAR2
# ENTER THE RATE2
# SIMPLE INTEREST= 400.0

# %%
base=int(input("ENTER THE BASE="))
height=int(input('ENTER THE HEIGHT='))
area = 0.5 * base * height
print('AREA=',area)
# Out:
# ENTER THE BASE=5
# ENTER THE HEIGHT=2
# AREA= 5.0
