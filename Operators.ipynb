# %%
n1=int(input("ENTER N1= "))
n2=int(input("ENTER N2=" ))
c=n1/n2
d=n1%n2
print("DIVISION=",c)
print("REMINDER=",d)
# Out:
# ENTER N1= 8
# ENTER N2=2
# DIVISION= 4.0
# REMINDER= 0

# %%
a=10
a+=5
print(a)
# Out:
# 15

# %%
n1=int(input("ENTER N1= "))
n2=int(input("ENTER N2=" ))
c=n1+n2
d=n1-n2
e=n1*n2
f=n1/n2
g=n1%n2
h=n1//n2
print("ADDISION=",c)
print("SUBSTRACTION=",d)
print("MULTIPLICATION=",e)
print("DIVISION=",f)
print("REMINDER=",g)
print("FLOOR DIVISION",h)
# Out:
# ENTER N1= 10
# ENTER N2=3
# ADDISION= 13
# SUBSTRACTION= 7
# MULTIPLICATION= 30
# DIVISION= 3.3333333333333335
# REMINDER= 1
# FLOOR DIVISION 3

# %%
cel=float(input("ENTER CELCIUS= "))
far=cel*9/5*32
print(cel,"CELCIUS= ",far,"FAHRENHEIT")
# Out:
# ENTER CELCIUS= 5
# 5.0 CELCIUS=  288.0 FAHRENHEIT

# %%
n1=int(input("ENTER THE FIRST NUMBER "))
n2=int(input("ENTER THE SECOND NUMBER "))
n3=int(input("ENTER THE THIRD NUMBER "))
c=(n1+n2+n3)/3
print("AVG= ",c)
# Out:
# ENTER THE FIRST NUMBER 1
# ENTER THE SECOND NUMBER 2
# ENTER THE THIRD NUMBER 3
# AVG=  2.0

# %%
far=float(input("ENTER FAHRENHEIT" ))
cel=(far-32)*5/9
print(far,"FAHRENHEIT ", cel,"CELCIUS")
# Out:
# ENTER FAHRENHEIT4
# 4.0 FAHRENHEIT  -15.555555555555555 CELCIUS
